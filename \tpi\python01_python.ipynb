# %% [markdown]
# <a href="https://colab.research.google.com/github/DALBO-creator/QUARTA/blob/main/%5Ctpi%5Cpython01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python è un linguaggio di programmazione ad alto livello progettato per rendere la scrittura di programmi più intuitiva
# (più vicno all'utente che alla memoria).

# %% [markdown]
# Python è un linguaggio interpretrato a livello di bytecode (è un linguaggio intermedio tra assembly e alto livello): il codice sorgente vciene prima tradotto in formato intermedio e poi eseguito dall'interprete PYTHON.

# %%
nome = "Davide"
cognome = "Albo"
punteggio = 85

# print(nome, cognome)
# type(nome)
# type(45.0)

print (f"il giocatore {nome}, ha ottenuto questo punteggio: {punteggio}")
# Out:
# il giocatore Davide, ha ottenuto questo punteggio: 85
